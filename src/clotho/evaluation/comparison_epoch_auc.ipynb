# %%
from os import path
import pickle
import torch
import random
import numpy as np
import torch.nn.functional as F
from torch_geometric.nn import GATConv, GCNConv, SAGEConv
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from clotho.model.data_loader import get_data_loader
from clotho.model.new_data_loader import get_new_data_loader

def sample_one_degree_ego_network(edge_index, num_samples=10):
    ego_networks = {}
    for source_node, target_node in edge_index.t():
        if source_node.item() not in ego_networks:
            ego_networks[source_node.item()] = set()
        ego_networks[source_node.item()].add(target_node.item())
    for node in ego_networks:
        ego_networks[node] = list(ego_networks[node])
    return ego_networks

class CustomGraphSAGENet(torch.nn.Module):
    def __init__(self, num_features, num_classes, aggregation_type='mean'):
        super(CustomGraphSAGENet, self).__init__()
        self.conv1 = SAGEConv(num_features, 16, aggr=aggregation_type)
        self.conv2 = SAGEConv(16, num_classes, aggr=aggregation_type)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)

        ego_networks = sample_one_degree_ego_network(edge_index)
        aggregated_features = torch.zeros_like(x)
        for node, neighbors in ego_networks.items():
            neighbors_tensor = torch.tensor(neighbors, dtype=torch.long, device=x.device)
            aggregated_features[node] = x[neighbors_tensor].mean(dim=0)
        return aggregated_features

class GCNNet(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super(GCNNet, self).__init__()
        self.conv1 = GCNConv(num_features, 16)
        self.conv2 = GCNConv(16, num_classes)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x

class GraphSAGENet(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super(GraphSAGENet, self).__init__()
        self.conv1 = SAGEConv(num_features, 16)
        self.conv2 = SAGEConv(16, num_classes)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)
        return x

class Net(torch.nn.Module):
    def __init__(self):
        super().__init__()
        num_features = 4
        num_classes = 3
        self.conv1 = GATConv(num_features, 8, heads=2)
        self.lin1 = torch.nn.Linear(num_features, 2 * 8)
        self.conv2 = GATConv(2 * 8, 8, heads=2)
        self.lin2 = torch.nn.Linear(2 * 8, 2 * 8)
        self.conv3 = GATConv(2 * 8, num_classes, heads=2, concat=False)
        self.lin3 = torch.nn.Linear(2 * 8, num_classes)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index) + self.lin1(x))
        x = F.elu(self.conv2(x, edge_index) + self.lin2(x))
        x = self.conv3(x, edge_index) + self.lin3(x)
        return x

train_loader, test_loader = get_data_loader()
new_train_loader, new_test_loader = get_new_data_loader()

def run_experiment(model):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
    loss_op = torch.nn.BCEWithLogitsLoss()

    def train():
        model.train()
        total_loss = 0
        for data in train_loader:
            data = data.to(device)
            optimizer.zero_grad()
            output = model(data.x, data.edge_index)
            if torch.isnan(output).any() or torch.isinf(output).any():
                print("NaN or Inf in model output")
                continue
            loss = loss_op(output, data.y.float())
            if torch.isnan(loss) or torch.isinf(loss):
                print("NaN or Inf in loss")
                continue
            total_loss += loss.item() * data.num_graphs
            loss.backward()
            optimizer.step()
        return total_loss / len(train_loader.dataset)

    @torch.no_grad()
    def test(loader):
        model.eval()
        all_probs, all_labels = [], []
        for data in loader:
            data = data.to(device)
            out = model(data.x, data.edge_index)
            all_probs.append(out.cpu())
            all_labels.append(data.y.cpu())
        return all_probs, all_labels

    average_auc_scores = []
    for epoch in range(1, 101):
        train()
        probs, labels = test(test_loader)
        probs = torch.cat(probs, dim=0).sigmoid().numpy()
        labels = torch.cat(labels, dim=0).numpy()
        auc_scores = []
        for i in range(labels.shape[1]):
            fpr, tpr, _ = roc_curve(labels[:, i], probs[:, i])
            roc_auc = auc(fpr, tpr)
            auc_scores.append(roc_auc)
        average_auc = np.mean(auc_scores)
        average_auc_scores.append(average_auc)
        print(f"Epoch: {epoch:03d}, Average AUC: {average_auc:.4f}")

    plt.plot(range(1, 101), average_auc_scores, label="Average AUC")
    plt.xlabel("Epoch")
    plt.ylabel("Average AUC")
    plt.title("Average AUC per Epoch")
    plt.legend()
    plt.show()
    return average_auc_scores

num_features = 4  # Adjust this based on your dataset
num_classes = 3   # Adjust this based on your dataset

print("Running GAT Experiment")
gat_auc_scores = run_experiment(Net())

print("\nRunning GCN Experiment")
gcn_auc_scores = run_experiment(GCNNet(num_features, num_classes))

print("\nRunning GraphSAGE Experiment")
graphsage_auc_scores = run_experiment(GraphSAGENet(num_features, num_classes))

print("\nRunning Custom GraphSAGE Experiment")
custom_graphsage_auc_scores = run_experiment(CustomGraphSAGENet(num_features, num_classes, aggregation_type='max'))

plt.figure(figsize=(10, 6))
epochs = range(1, 101)
plt.plot(epochs, gat_auc_scores, label="GAT")
plt.plot(epochs, gcn_auc_scores, label="GCN")
plt.plot(epochs, graphsage_auc_scores, label="GraphSAGE")
plt.plot(epochs, custom_graphsage_auc_scores, label="Custom GraphSAGE")
plt.xlabel("Epoch")
plt.ylabel("Average AUC")
plt.title("Average AUC per Epoch for GAT, GCN, GraphSAGE, and Custom GraphSAGE")
plt.legend()
plt.show()
# Out:
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:74: RuntimeWarning: invalid value encountered in divide
#   D[i] = D[i] / np.sum(D[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:81: RuntimeWarning: invalid value encountered in divide
#   P[i] = P[i] / np.sum(P[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# train_data_prepared
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:74: RuntimeWarning: invalid value encountered in divide
#   D[i] = D[i] / np.sum(D[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:81: RuntimeWarning: invalid value encountered in divide
#   P[i] = P[i] / np.sum(P[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:67: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:74: RuntimeWarning: invalid value encountered in divide
#   D[i] = D[i] / np.sum(D[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:81: RuntimeWarning: invalid value encountered in divide
#   P[i] = P[i] / np.sum(P[i])
# Processing key: 1INCH
# Processing key: AAVE
# Skipping key ACA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ACM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ADA
# Processing key: ADX
# Skipping key AE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AERGO
# Processing key: AGI
# Processing key: AGIX
# Skipping key AGLD: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AION
# Skipping key AKRO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ALCX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ALGO
# Processing key: ALICE
# Skipping key ALPACA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ALPHA
# Skipping key ALPINE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AMB
# Skipping key ANC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ANKR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ANT
# Skipping key ANY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: APE
# Skipping key API3: Column 'telegram_chat_id' not found in DataFrame
# Processing key: APPC
# Skipping key AR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ARDR
# Processing key: ARK
# Processing key: ARN
# Processing key: ARPA
# Skipping key ASR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AST
# Skipping key ASTR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ATA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ATM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ATOM
# Skipping key AUCTION: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AUDIO
# Skipping key AVA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AVAX
# Processing key: AXS
# Skipping key BADGER: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BAKE
# Processing key: BAL
# Processing key: BAND
# Skipping key BAR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BAT
# Processing key: BCD
# Processing key: BCH
# Processing key: BCPT
# Skipping key BEAM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BEL
# Skipping key BETA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BICO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BLZ
# Processing key: BNB
# Skipping key BNX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOND: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BQX
# Processing key: BRD
# Processing key: BTC
# Skipping key BTG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BZRX
# Skipping key C98: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CAKE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CDT
# Processing key: CELO
# Processing key: CELR
# Skipping key CFX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CHR
# Processing key: CHZ
# Skipping key CKB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CLV: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CMT
# Skipping key CND: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COMP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: COTI
# Processing key: CRV
# Skipping key CTK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CTSI
# Processing key: CTXC
# Processing key: CVC
# Skipping key CVP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DASH
# Processing key: DATA
# Skipping key DCR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DEGO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DF: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DGB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DGD: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DIA
# Processing key: DLT
# Processing key: DNT
# Processing key: DOCK
# Processing key: DODO
# Processing key: DOGE
# Processing key: DOT
# Processing key: DREP
# Processing key: DUSK
# Processing key: DYDX
# Skipping key EASY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EDO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: EGLD
# Processing key: ELF
# Processing key: ENG
# Processing key: ENJ
# Skipping key ENS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: EOS
# Processing key: EPS
# Skipping key ERD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ERN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ETC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ETH
# Skipping key EUR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: EVX
# Skipping key EZ: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FARM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FET
# Skipping key FIDA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FIL
# Processing key: FIO
# Skipping key FIRO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FIS
# Skipping key FLM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FLOW: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FLUX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FORTH: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FRONT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FTM
# Skipping key FTT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FUEL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FUN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FXS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GAL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GALA
# Skipping key GAS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GLM
# Skipping key GLMR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GNT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GRS
# Processing key: GRT
# Skipping key GTC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GTO
# Skipping key GVT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GXS
# Processing key: HBAR
# Skipping key HC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key HIGH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: HIVE
# Processing key: HNT
# Skipping key HOT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ICP
# Skipping key ICX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: IDEX
# Skipping key IMX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: INJ
# Processing key: INS
# Processing key: IOST
# Skipping key IOTA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key IOTX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: IRIS
# Skipping key JASMY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key JST: Column 'telegram_chat_id' not found in DataFrame
# Skipping key JUV: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KAVA
# Skipping key KDON: Column 'telegram_chat_id' not found in DataFrame
# Skipping key KEEP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key KEY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key KLAY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KMD
# Processing key: KNC
# Skipping key KSM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key LAZIO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LEND
# Skipping key LINA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LINK
# Skipping key LIT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key LOKA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LOOM
# Skipping key LPT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LRC
# Skipping key LSK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LTC
# Processing key: LTO
# Skipping key LUN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LUNA
# Processing key: MANA
# Skipping key MASK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MATIC
# Skipping key MBL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MBOX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MDA
# Processing key: MDT
# Skipping key MDX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MINA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MIR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MITH
# Processing key: MKR
# Skipping key MOVR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MTH
# Processing key: MTL
# Skipping key MULTI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NANO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NAS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NAV
# Skipping key NBS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NBT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NEAR
# Processing key: NEBL
# Skipping key NEO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NKN
# Skipping key NMR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NU: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NULS
# Skipping key NXS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OAX
# Skipping key OCEAN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OGN
# Processing key: OM
# Processing key: OMG
# Processing key: ONG
# Skipping key ONT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OOKI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ORN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OST
# Processing key: OXT
# Skipping key PAXG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PEOPLE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PERL
# Skipping key PERP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PHA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PHB
# Skipping key PHX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PIVX
# Skipping key PLA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PNT
# Processing key: POA
# Skipping key POE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: POLY
# Processing key: POND
# Skipping key PORTO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: POWR
# Processing key: PPT
# Skipping key PSG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PYR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key QKC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: QLC
# Processing key: QSP
# Processing key: QTUM
# Skipping key RAD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key RARE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key RAY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RCN
# Processing key: RDN
# Skipping key REEF: Column 'telegram_chat_id' not found in DataFrame
# Processing key: REN
# Skipping key REP: Column 'telegram_chat_id' not found in DataFrame
# Processing key: REQ
# Skipping key RIF: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RLC
# Skipping key ROSE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RSR
# Processing key: RUNE
# Processing key: RVN
# Processing key: SAND
# Skipping key SANTOS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SCRT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SFP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SHIB: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SKL
# Processing key: SKY
# Skipping key SLP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SNGLS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SNX
# Processing key: SOL
# Processing key: SRM
# Skipping key SSV: Column 'telegram_chat_id' not found in DataFrame
# Processing key: STEEM
# Skipping key STMX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: STORJ
# Skipping key STORM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: STPT
# Skipping key STRAT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key STRAX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key STX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SUN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SUSHI
# Processing key: SXP
# Processing key: SYS
# Processing key: TCT
# Processing key: TFUEL
# Processing key: THETA
# Skipping key TKO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TLM
# Skipping key TNB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key TNT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TOMO
# Skipping key TORN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TRB
# Skipping key TROY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TRU
# Processing key: TRX
# Processing key: TVK
# Skipping key TWT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key UMA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key UNFI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: UNI
# Skipping key UST: Column 'telegram_chat_id' not found in DataFrame
# Processing key: UTK
# Processing key: VET
# Skipping key VGX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: VIA
# Processing key: VIB
# Processing key: VIBE
# Processing key: VIDT
# Processing key: VITE
# Skipping key VOXEL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: WABI
# Processing key: WAN
# Processing key: WAVES
# Skipping key WING: Column 'telegram_chat_id' not found in DataFrame
# Processing key: WRX
# Processing key: WTC
# Skipping key XBT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XEM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: XLM
# Skipping key XMR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XNO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: XRP
# Processing key: XTZ
# Skipping key XVG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XVS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XZC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: YFI
# Processing key: YFII
# Skipping key YGG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key YOYO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ZEC
# Processing key: ZEN
# Processing key: ZIL
# Skipping key ZRX: Column 'telegram_chat_id' not found in DataFrame
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# train_data_prepared
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:67: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:74: RuntimeWarning: invalid value encountered in divide
#   D[i] = D[i] / np.sum(D[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:81: RuntimeWarning: invalid value encountered in divide
#   P[i] = P[i] / np.sum(P[i])
# Skipping key 1000LUNC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key 1CAT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key 1EARTH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: 1INCH
# Processing key: AAVE
# Skipping key ABBC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ACA
# Processing key: ACE
# Processing key: ACH
# Skipping key ACM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ACQ: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ACS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ACT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ADA
# Skipping key ADS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ADX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AERGO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AGIX
# Processing key: AGLD
# Processing key: AI
# Skipping key AIPAD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AKITA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AKRO
# Skipping key AKT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ALCX
# Skipping key ALEPH: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ALEX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ALGO
# Processing key: ALICE
# Processing key: ALPACA
# Processing key: ALPHA
# Processing key: ALPINE
# Skipping key ALT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AMB
# Processing key: AMP
# Skipping key AMPL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ANKR
# Processing key: ANT
# Skipping key AOG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: APE
# Processing key: API3
# Skipping key APM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key APP: Column 'telegram_chat_id' not found in DataFrame
# Processing key: APT
# Processing key: AR
# Processing key: ARB
# Skipping key ARDR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ARG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ARIX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ARK
# Skipping key ARKER: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ARKM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ARPA
# Skipping key ARTY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ARX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ASR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AST
# Skipping key ASTR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ASTRA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ATA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ATM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ATOM
# Skipping key ATOR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AUCTION
# Processing key: AUDIO
# Skipping key AURORA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AUSD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AUTO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AVA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AVAX
# Processing key: AXS
# Skipping key AZERO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AZY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BABY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BABYDOGE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BADGER
# Processing key: BAKE
# Processing key: BAL
# Processing key: BAND
# Processing key: BAR
# Processing key: BAT
# Skipping key BAX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BBC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BCH
# Skipping key BDX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BEL
# Skipping key BEPRO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BETA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BETH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BICO
# Processing key: BIFI
# Skipping key BLOK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BLUR
# Processing key: BLZ
# Processing key: BNB
# Skipping key BNBDOWN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BNBUP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BNT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BNX
# Skipping key BOA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOBA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOLT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BOND
# Skipping key BONDLY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BONE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BONK: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BORA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BORING: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOSON: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BRISE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BRWL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BSV: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BSW: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BTC
# Skipping key BTC3L: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTC3S: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTCDOWN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTCUP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BULL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BURGER
# Skipping key BZZ: Column 'telegram_chat_id' not found in DataFrame
# Processing key: C98
# Skipping key CAKE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CANDY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CAPO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CAPP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CCD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CEEK: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CEL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CELO
# Processing key: CELR
# Skipping key CERE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CETUS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CFG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CFX
# Skipping key CGL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CGPT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CHESS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CHMB: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CHR
# Processing key: CHZ
# Skipping key CITY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CKB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CLH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CLV
# Skipping key CMP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COCOS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COMBO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: COMP
# Skipping key CONV: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CORE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: COS
# Processing key: COTI
# Skipping key CPOOL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CQT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CREAM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CREDI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CRO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CRV
# Skipping key CSIX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CSPR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CTC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CTI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CTK
# Processing key: CTSI
# Skipping key CTXC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CVC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CVP
# Processing key: CVX
# Skipping key CWAR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CWEB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CWS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CYBER: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAPPX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DASH
# Skipping key DATA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DBC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DCK: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DCR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DEGO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DENT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DEP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DERC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DEXE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DFI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DGB
# Processing key: DIA
# Skipping key DIVI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DMTR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DOCK
# Processing key: DODO
# Processing key: DOGE
# Skipping key DOME: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DORA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DOSE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DOT
# Skipping key DPR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DREAMS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DREP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DSLA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DUSK
# Skipping key DVPN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DYDX
# Skipping key EDU: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EGAME: Column 'telegram_chat_id' not found in DataFrame
# Processing key: EGLD
# Skipping key EGO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ELF
# Skipping key ELON: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ENJ
# Processing key: ENS
# Processing key: EOS
# Skipping key EOSC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EPIK: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EPX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ERG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ERN
# Skipping key ERTHA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ETC
# Processing key: ETH
# Skipping key ETHDOWN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ETHUP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ETHW: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EVMOS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EWT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FARM
# Processing key: FET
# Processing key: FIDA
# Processing key: FIL
# Skipping key FIO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FIRO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FIS
# Skipping key FITFI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FLIP: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FLM
# Skipping key FLOKI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FLOW
# Skipping key FLR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FLUX
# Skipping key FORTH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FRONT
# Processing key: FTM
# Processing key: FTT
# Processing key: FUN
# Processing key: FXS
# Processing key: GAL
# Processing key: GALA
# Skipping key GARI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GAS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GEARBOX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GFT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GHST: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GLM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GLMR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GMX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GNO
# Skipping key GNS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GODS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GOG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GRT
# Processing key: GTC
# Processing key: HBAR
# Skipping key HFT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: HIFI
# Processing key: HIGH
# Skipping key HIVE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: HNT
# Processing key: HOOK
# Processing key: HOT
# Processing key: ICP
# Processing key: ICX
# Skipping key ID: Column 'telegram_chat_id' not found in DataFrame
# Skipping key IDEX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key IGU: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ILV
# Processing key: IMX
# Processing key: INJ
# Processing key: IOST
# Processing key: IOTA
# Processing key: IOTX
# Skipping key IRIS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key JAM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: JASMY
# Processing key: JOE
# Skipping key JST: Column 'telegram_chat_id' not found in DataFrame
# Skipping key JTO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: JUV
# Skipping key KAR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KAVA
# Skipping key KCS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KDA
# Skipping key KEY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key KINE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KLAY
# Skipping key KMD: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KNC
# Skipping key KONO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KP3R
# Processing key: KSM
# Skipping key KSMU: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LAZIO
# Skipping key LBR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LDO
# Skipping key LEASH: Column 'telegram_chat_id' not found in DataFrame
# Skipping key LET: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LEVER
# Processing key: LINA
# Skipping key LING: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LINK
# Processing key: LIT
# Skipping key LITH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LOKA
# Skipping key LOOKS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LOOM
# Processing key: LPT
# Processing key: LQTY
# Processing key: LRC
# Skipping key LSK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LTC
# Processing key: LTO
# Skipping key LUNA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key LUNC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MAGIC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MANA
# Processing key: MASK
# Processing key: MATIC
# Processing key: MAV
# Skipping key MBL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MBOX
# Skipping key MC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MDT
# Processing key: MDX
# Skipping key MENGO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MINA
# Skipping key MIR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MITH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MKR
# Processing key: MLN
# Skipping key MOB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MOVEZ: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MOVR
# Skipping key MRST: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MTL
# Processing key: MULTI
# Processing key: NEAR
# Skipping key NEBL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NEO
# Skipping key NEXO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NFP
# Skipping key NIM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NKN
# Processing key: NMR
# Skipping key NOIA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NTRN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NULS
# Skipping key NYM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OAS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OAX
# Processing key: OCEAN
# Processing key: OGN
# Skipping key OKB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OKT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OLT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OM
# Processing key: OMG
# Skipping key OMI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OMN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ONG
# Processing key: ONT
# Skipping key OOKI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OP
# Skipping key ORB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ORBS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ORDI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ORN
# Skipping key OSMO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OXT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PAXG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PCI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PENDLE
# Processing key: PEOPLE
# Skipping key PEPE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PERL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PERP
# Processing key: PHA
# Processing key: PHB
# Processing key: PIVX
# Skipping key PLA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PNT
# Skipping key POLS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key POLYX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key POND: Column 'telegram_chat_id' not found in DataFrame
# Skipping key POR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PORTO
# Processing key: POWR
# Processing key: PROM
# Processing key: PROS
# Processing key: PSG
# Skipping key PUNDIX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PYR
# Processing key: PYTH
# Processing key: QLC
# Processing key: QNT
# Processing key: QTUM
# Processing key: QUICK
# Skipping key RACA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RAD
# Processing key: RARE
# Processing key: RAY
# Skipping key RDNT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: REEF
# Processing key: REI
# Processing key: REN
# Skipping key REP: Column 'telegram_chat_id' not found in DataFrame
# Processing key: REQ
# Skipping key REVV: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RIF
# Skipping key RIO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RLC
# Processing key: RNDR
# Processing key: ROSE
# Skipping key RPL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RSR
# Processing key: RUNE
# Processing key: RVN
# Skipping key SAMO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SAND
# Processing key: SANTOS
# Processing key: SC
# Processing key: SCRT
# Processing key: SEI
# Skipping key SENSO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SFP
# Skipping key SHIB: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SKL
# Processing key: SLP
# Skipping key SNM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SNT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SNX
# Processing key: SOL
# Skipping key SOUL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SPELL
# Processing key: SRM
# Processing key: SSV
# Skipping key SSWP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key STARL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key STC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key STEEM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: STG
# Processing key: STMX
# Processing key: STORJ
# Skipping key STPT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: STRAX
# Processing key: STX
# Processing key: SUI
# Processing key: SUN
# Processing key: SUPER
# Processing key: SUSHI
# Skipping key SWEAT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SXP
# Processing key: SYN
# Processing key: SYS
# Skipping key TAKI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key TAMA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key TFUEL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: THETA
# Processing key: TIA
# Skipping key TKO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TLM
# Skipping key TOKEN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TOMO
# Skipping key TORN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key TRADE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TRB
# Skipping key TRIAS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key TROY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TRU
# Processing key: TRX
# Processing key: TVK
# Processing key: TWT
# Processing key: UFT
# Processing key: UMA
# Processing key: UNFI
# Processing key: UNI
# Processing key: USTC
# Processing key: UTK
# Skipping key VANRY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: VET
# Processing key: VGX
# Processing key: VIB
# Skipping key VIC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: VIDT
# Skipping key VITE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: VOXEL
# Skipping key VRA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key VTHO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key WABI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key WAN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: WAVES
# Processing key: WAXP
# Skipping key WBTC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: WING
# Processing key: WLD
# Processing key: WOO
# Processing key: WRX
# Skipping key WTC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: XAI
# Skipping key XCUR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XEC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XEM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: XLM
# Processing key: XMR
# Skipping key XNO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: XRP
# Skipping key XTM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: XTZ
# Processing key: XVG
# Processing key: XVS
# Processing key: YFI
# Skipping key YFII: Column 'telegram_chat_id' not found in DataFrame
# Processing key: YGG
# Processing key: ZEC
# Processing key: ZEN
# Processing key: ZIL
# Processing key: ZRX
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:67: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# NaN values detected in key: BQX, Columns: ['out_ratio']
# NaN values detected in key: STPT, Columns: ['in_ratio', 'out_ratio']
# NaN values detected in key: BURGER, Columns: ['number_of_signals']
# NaN values detected in key: COS, Columns: ['average_increase_percentage']
# NaN values detected in key: CVP, Columns: ['number_of_signals']
# NaN values detected in key: CVX, Columns: ['number_of_signals']
# NaN values detected in key: FIDA, Columns: ['number_of_signals']
# NaN values detected in key: FXS, Columns: ['number_of_signals']
# NaN values detected in key: GNO, Columns: ['number_of_signals']
# NaN values detected in key: JUV, Columns: ['number_of_signals']
# NaN values detected in key: KDA, Columns: ['number_of_signals']
# NaN values detected in key: KP3R, Columns: ['number_of_signals']
# NaN values detected in key: LAZIO, Columns: ['number_of_signals']
# NaN values detected in key: MLN, Columns: ['number_of_signals']
# NaN values detected in key: NFP, Columns: ['average_increase_percentage', 'number_of_signals']
# NaN values detected in key: PORTO, Columns: ['number_of_signals']
# NaN values detected in key: PROM, Columns: ['number_of_signals']
# NaN values detected in key: PSG, Columns: ['number_of_signals']
# NaN values detected in key: PYTH, Columns: ['number_of_signals']
# NaN values detected in key: SC, Columns: ['number_of_signals']
# NaN values detected in key: SLP, Columns: ['number_of_signals']
# NaN values detected in key: SPELL, Columns: ['number_of_signals']
# NaN values detected in key: SUN, Columns: ['number_of_signals']
# NaN values detected in key: USTC, Columns: ['number_of_signals']
# NaN values detected in key: VIDT, Columns: ['number_of_signals']
# NaN values detected in key: VOXEL, Columns: ['number_of_signals']
# NaN values detected in key: WING, Columns: ['number_of_signals']
# NaN values detected in key: XAI, Columns: ['number_of_signals']
# NaN values detected in key: XVG, Columns: ['number_of_signals']
# Running GAT Experiment
# Epoch: 001, Average AUC: 0.6053
# Epoch: 002, Average AUC: 0.6116
# Epoch: 003, Average AUC: 0.6198
# Epoch: 004, Average AUC: 0.6290
# Epoch: 005, Average AUC: 0.6400
# Epoch: 006, Average AUC: 0.6532
# Epoch: 007, Average AUC: 0.6692
# Epoch: 008, Average AUC: 0.6893
# Epoch: 009, Average AUC: 0.7137
# Epoch: 010, Average AUC: 0.7415
# Epoch: 011, Average AUC: 0.7715
# Epoch: 012, Average AUC: 0.7980
# Epoch: 013, Average AUC: 0.8195
# Epoch: 014, Average AUC: 0.8350
# Epoch: 015, Average AUC: 0.8465
# Epoch: 016, Average AUC: 0.8557
# Epoch: 017, Average AUC: 0.8633
# Epoch: 018, Average AUC: 0.8701
# Epoch: 019, Average AUC: 0.8760
# Epoch: 020, Average AUC: 0.8811
# Epoch: 021, Average AUC: 0.8856
# Epoch: 022, Average AUC: 0.8900
# Epoch: 023, Average AUC: 0.8938
# Epoch: 024, Average AUC: 0.8972
# Epoch: 025, Average AUC: 0.9002
# Epoch: 026, Average AUC: 0.9030
# Epoch: 027, Average AUC: 0.9056
# Epoch: 028, Average AUC: 0.9080
# Epoch: 029, Average AUC: 0.9102
# Epoch: 030, Average AUC: 0.9125
# Epoch: 031, Average AUC: 0.9145
# Epoch: 032, Average AUC: 0.9164
# Epoch: 033, Average AUC: 0.9180
# Epoch: 034, Average AUC: 0.9199
# Epoch: 035, Average AUC: 0.9214
# Epoch: 036, Average AUC: 0.9228
# Epoch: 037, Average AUC: 0.9241
# Epoch: 038, Average AUC: 0.9254
# Epoch: 039, Average AUC: 0.9269
# Epoch: 040, Average AUC: 0.9281
# Epoch: 041, Average AUC: 0.9295
# Epoch: 042, Average AUC: 0.9307
# Epoch: 043, Average AUC: 0.9319
# Epoch: 044, Average AUC: 0.9329
# Epoch: 045, Average AUC: 0.9339
# Epoch: 046, Average AUC: 0.9350
# Epoch: 047, Average AUC: 0.9358
# Epoch: 048, Average AUC: 0.9372
# Epoch: 049, Average AUC: 0.9377
# Epoch: 050, Average AUC: 0.9390
# Epoch: 051, Average AUC: 0.9398
# Epoch: 052, Average AUC: 0.9408
# Epoch: 053, Average AUC: 0.9416
# Epoch: 054, Average AUC: 0.9424
# Epoch: 055, Average AUC: 0.9432
# Epoch: 056, Average AUC: 0.9440
# Epoch: 057, Average AUC: 0.9447
# Epoch: 058, Average AUC: 0.9451
# Epoch: 059, Average AUC: 0.9458
# Epoch: 060, Average AUC: 0.9467
# Epoch: 061, Average AUC: 0.9471
# Epoch: 062, Average AUC: 0.9477
# Epoch: 063, Average AUC: 0.9483
# Epoch: 064, Average AUC: 0.9487
# Epoch: 065, Average AUC: 0.9494
# Epoch: 066, Average AUC: 0.9498
# Epoch: 067, Average AUC: 0.9503
# Epoch: 068, Average AUC: 0.9506
# Epoch: 069, Average AUC: 0.9512
# Epoch: 070, Average AUC: 0.9517
# Epoch: 071, Average AUC: 0.9521
# Epoch: 072, Average AUC: 0.9524
# Epoch: 073, Average AUC: 0.9528
# Epoch: 074, Average AUC: 0.9531
# Epoch: 075, Average AUC: 0.9536
# Epoch: 076, Average AUC: 0.9540
# Epoch: 077, Average AUC: 0.9543
# Epoch: 078, Average AUC: 0.9546
# Epoch: 079, Average AUC: 0.9551
# Epoch: 080, Average AUC: 0.9552
# Epoch: 081, Average AUC: 0.9557
# Epoch: 082, Average AUC: 0.9558
# Epoch: 083, Average AUC: 0.9561
# Epoch: 084, Average AUC: 0.9565
# Epoch: 085, Average AUC: 0.9568
# Epoch: 086, Average AUC: 0.9570
# Epoch: 087, Average AUC: 0.9572
# Epoch: 088, Average AUC: 0.9573
# Epoch: 089, Average AUC: 0.9576
# Epoch: 090, Average AUC: 0.9578
# Epoch: 091, Average AUC: 0.9581
# Epoch: 092, Average AUC: 0.9582
# Epoch: 093, Average AUC: 0.9584
# Epoch: 094, Average AUC: 0.9585
# Epoch: 095, Average AUC: 0.9587
# Epoch: 096, Average AUC: 0.9589
# Epoch: 097, Average AUC: 0.9591
# Epoch: 098, Average AUC: 0.9593
# Epoch: 099, Average AUC: 0.9594
# Epoch: 100, Average AUC: 0.9596
# Running GCN Experiment
# Epoch: 001, Average AUC: 0.4497
# Epoch: 002, Average AUC: 0.4464
# Epoch: 003, Average AUC: 0.4433
# Epoch: 004, Average AUC: 0.4402
# Epoch: 005, Average AUC: 0.4372
# Epoch: 006, Average AUC: 0.4349
# Epoch: 007, Average AUC: 0.4325
# Epoch: 008, Average AUC: 0.4307
# Epoch: 009, Average AUC: 0.4292
# Epoch: 010, Average AUC: 0.4278
# Epoch: 011, Average AUC: 0.4267
# Epoch: 012, Average AUC: 0.4258
# Epoch: 013, Average AUC: 0.4248
# Epoch: 014, Average AUC: 0.4241
# Epoch: 015, Average AUC: 0.4233
# Epoch: 016, Average AUC: 0.4229
# Epoch: 017, Average AUC: 0.4223
# Epoch: 018, Average AUC: 0.4220
# Epoch: 019, Average AUC: 0.4216
# Epoch: 020, Average AUC: 0.4214
# Epoch: 021, Average AUC: 0.4213
# Epoch: 022, Average AUC: 0.4212
# Epoch: 023, Average AUC: 0.4212
# Epoch: 024, Average AUC: 0.4211
# Epoch: 025, Average AUC: 0.4214
# Epoch: 026, Average AUC: 0.4216
# Epoch: 027, Average AUC: 0.4218
# Epoch: 028, Average AUC: 0.4219
# Epoch: 029, Average AUC: 0.4222
# Epoch: 030, Average AUC: 0.4225
# Epoch: 031, Average AUC: 0.4229
# Epoch: 032, Average AUC: 0.4232
# Epoch: 033, Average AUC: 0.4236
# Epoch: 034, Average AUC: 0.4241
# Epoch: 035, Average AUC: 0.4247
# Epoch: 036, Average AUC: 0.4253
# Epoch: 037, Average AUC: 0.4260
# Epoch: 038, Average AUC: 0.4266
# Epoch: 039, Average AUC: 0.4272
# Epoch: 040, Average AUC: 0.4279
# Epoch: 041, Average AUC: 0.4284
# Epoch: 042, Average AUC: 0.4289
# Epoch: 043, Average AUC: 0.4297
# Epoch: 044, Average AUC: 0.4302
# Epoch: 045, Average AUC: 0.4309
# Epoch: 046, Average AUC: 0.4315
# Epoch: 047, Average AUC: 0.4321
# Epoch: 048, Average AUC: 0.4328
# Epoch: 049, Average AUC: 0.4337
# Epoch: 050, Average AUC: 0.4343
# Epoch: 051, Average AUC: 0.4348
# Epoch: 052, Average AUC: 0.4355
# Epoch: 053, Average AUC: 0.4361
# Epoch: 054, Average AUC: 0.4370
# Epoch: 055, Average AUC: 0.4376
# Epoch: 056, Average AUC: 0.4384
# Epoch: 057, Average AUC: 0.4389
# Epoch: 058, Average AUC: 0.4396
# Epoch: 059, Average AUC: 0.4403
# Epoch: 060, Average AUC: 0.4409
# Epoch: 061, Average AUC: 0.4416
# Epoch: 062, Average AUC: 0.4422
# Epoch: 063, Average AUC: 0.4431
# Epoch: 064, Average AUC: 0.4437
# Epoch: 065, Average AUC: 0.4445
# Epoch: 066, Average AUC: 0.4451
# Epoch: 067, Average AUC: 0.4458
# Epoch: 068, Average AUC: 0.4465
# Epoch: 069, Average AUC: 0.4473
# Epoch: 070, Average AUC: 0.4481
# Epoch: 071, Average AUC: 0.4489
# Epoch: 072, Average AUC: 0.4496
# Epoch: 073, Average AUC: 0.4503
# Epoch: 074, Average AUC: 0.4511
# Epoch: 075, Average AUC: 0.4520
# Epoch: 076, Average AUC: 0.4526
# Epoch: 077, Average AUC: 0.4534
# Epoch: 078, Average AUC: 0.4542
# Epoch: 079, Average AUC: 0.4548
# Epoch: 080, Average AUC: 0.4557
# Epoch: 081, Average AUC: 0.4563
# Epoch: 082, Average AUC: 0.4570
# Epoch: 083, Average AUC: 0.4578
# Epoch: 084, Average AUC: 0.4583
# Epoch: 085, Average AUC: 0.4591
# Epoch: 086, Average AUC: 0.4598
# Epoch: 087, Average AUC: 0.4605
# Epoch: 088, Average AUC: 0.4611
# Epoch: 089, Average AUC: 0.4619
# Epoch: 090, Average AUC: 0.4624
# Epoch: 091, Average AUC: 0.4633
# Epoch: 092, Average AUC: 0.4639
# Epoch: 093, Average AUC: 0.4647
# Epoch: 094, Average AUC: 0.4654
# Epoch: 095, Average AUC: 0.4661
# Epoch: 096, Average AUC: 0.4669
# Epoch: 097, Average AUC: 0.4675
# Epoch: 098, Average AUC: 0.4681
# Epoch: 099, Average AUC: 0.4688
# Epoch: 100, Average AUC: 0.4695
# Running GraphSAGE Experiment
# Epoch: 001, Average AUC: 0.6791
# Epoch: 002, Average AUC: 0.7020
# Epoch: 003, Average AUC: 0.7172
# Epoch: 004, Average AUC: 0.7304
# Epoch: 005, Average AUC: 0.7403
# Epoch: 006, Average AUC: 0.7506
# Epoch: 007, Average AUC: 0.7609
# Epoch: 008, Average AUC: 0.7695
# Epoch: 009, Average AUC: 0.7772
# Epoch: 010, Average AUC: 0.7843
# Epoch: 011, Average AUC: 0.7912
# Epoch: 012, Average AUC: 0.7981
# Epoch: 013, Average AUC: 0.8031
# Epoch: 014, Average AUC: 0.8087
# Epoch: 015, Average AUC: 0.8147
# Epoch: 016, Average AUC: 0.8202
# Epoch: 017, Average AUC: 0.8262
# Epoch: 018, Average AUC: 0.8318
# Epoch: 019, Average AUC: 0.8369
# Epoch: 020, Average AUC: 0.8421
# Epoch: 021, Average AUC: 0.8479
# Epoch: 022, Average AUC: 0.8528
# Epoch: 023, Average AUC: 0.8581
# Epoch: 024, Average AUC: 0.8624
# Epoch: 025, Average AUC: 0.8670
# Epoch: 026, Average AUC: 0.8717
# Epoch: 027, Average AUC: 0.8760
# Epoch: 028, Average AUC: 0.8806
# Epoch: 029, Average AUC: 0.8850
# Epoch: 030, Average AUC: 0.8891
# Epoch: 031, Average AUC: 0.8930
# Epoch: 032, Average AUC: 0.8969
# Epoch: 033, Average AUC: 0.9003
# Epoch: 034, Average AUC: 0.9037
# Epoch: 035, Average AUC: 0.9071
# Epoch: 036, Average AUC: 0.9102
# Epoch: 037, Average AUC: 0.9129
# Epoch: 038, Average AUC: 0.9157
# Epoch: 039, Average AUC: 0.9184
# Epoch: 040, Average AUC: 0.9210
# Epoch: 041, Average AUC: 0.9236
# Epoch: 042, Average AUC: 0.9260
# Epoch: 043, Average AUC: 0.9282
# Epoch: 044, Average AUC: 0.9304
# Epoch: 045, Average AUC: 0.9321
# Epoch: 046, Average AUC: 0.9340
# Epoch: 047, Average AUC: 0.9357
# Epoch: 048, Average AUC: 0.9373
# Epoch: 049, Average AUC: 0.9385
# Epoch: 050, Average AUC: 0.9398
# Epoch: 051, Average AUC: 0.9409
# Epoch: 052, Average AUC: 0.9421
# Epoch: 053, Average AUC: 0.9431
# Epoch: 054, Average AUC: 0.9443
# Epoch: 055, Average AUC: 0.9451
# Epoch: 056, Average AUC: 0.9460
# Epoch: 057, Average AUC: 0.9469
# Epoch: 058, Average AUC: 0.9476
# Epoch: 059, Average AUC: 0.9483
# Epoch: 060, Average AUC: 0.9490
# Epoch: 061, Average AUC: 0.9496
# Epoch: 062, Average AUC: 0.9502
# Epoch: 063, Average AUC: 0.9507
# Epoch: 064, Average AUC: 0.9512
# Epoch: 065, Average AUC: 0.9517
# Epoch: 066, Average AUC: 0.9522
# Epoch: 067, Average AUC: 0.9526
# Epoch: 068, Average AUC: 0.9530
# Epoch: 069, Average AUC: 0.9533
# Epoch: 070, Average AUC: 0.9537
# Epoch: 071, Average AUC: 0.9541
# Epoch: 072, Average AUC: 0.9545
# Epoch: 073, Average AUC: 0.9548
# Epoch: 074, Average AUC: 0.9551
# Epoch: 075, Average AUC: 0.9554
# Epoch: 076, Average AUC: 0.9556
# Epoch: 077, Average AUC: 0.9559
# Epoch: 078, Average AUC: 0.9563
# Epoch: 079, Average AUC: 0.9565
# Epoch: 080, Average AUC: 0.9568
# Epoch: 081, Average AUC: 0.9571
# Epoch: 082, Average AUC: 0.9573
# Epoch: 083, Average AUC: 0.9575
# Epoch: 084, Average AUC: 0.9578
# Epoch: 085, Average AUC: 0.9580
# Epoch: 086, Average AUC: 0.9581
# Epoch: 087, Average AUC: 0.9584
# Epoch: 088, Average AUC: 0.9585
# Epoch: 089, Average AUC: 0.9587
# Epoch: 090, Average AUC: 0.9589
# Epoch: 091, Average AUC: 0.9590
# Epoch: 092, Average AUC: 0.9592
# Epoch: 093, Average AUC: 0.9593
# Epoch: 094, Average AUC: 0.9595
# Epoch: 095, Average AUC: 0.9596
# Epoch: 096, Average AUC: 0.9598
# Epoch: 097, Average AUC: 0.9599
# Epoch: 098, Average AUC: 0.9600
# Epoch: 099, Average AUC: 0.9602
# Epoch: 100, Average AUC: 0.9602
# Running Custom GraphSAGE Experiment
# Epoch: 001, Average AUC: 0.6016
# Epoch: 002, Average AUC: 0.6070
# Epoch: 003, Average AUC: 0.6112
# Epoch: 004, Average AUC: 0.6129
# Epoch: 005, Average AUC: 0.6204
# Epoch: 006, Average AUC: 0.6292
# Epoch: 007, Average AUC: 0.6368
# Epoch: 008, Average AUC: 0.6444
# Epoch: 009, Average AUC: 0.6513
# Epoch: 010, Average AUC: 0.6595
# Epoch: 011, Average AUC: 0.6667
# Epoch: 012, Average AUC: 0.6722
# Epoch: 013, Average AUC: 0.6793
# Epoch: 014, Average AUC: 0.6863
# Epoch: 015, Average AUC: 0.6913
# Epoch: 016, Average AUC: 0.6961
# Epoch: 017, Average AUC: 0.7033
# Epoch: 018, Average AUC: 0.7067
# Epoch: 019, Average AUC: 0.7136
# Epoch: 020, Average AUC: 0.7197
# Epoch: 021, Average AUC: 0.7272
# Epoch: 022, Average AUC: 0.7299
# Epoch: 023, Average AUC: 0.7343
# Epoch: 024, Average AUC: 0.7397
# Epoch: 025, Average AUC: 0.7441
# Epoch: 026, Average AUC: 0.7478
# Epoch: 027, Average AUC: 0.7517
# Epoch: 028, Average AUC: 0.7569
# Epoch: 029, Average AUC: 0.7592
# Epoch: 030, Average AUC: 0.7613
# Epoch: 031, Average AUC: 0.7630
# Epoch: 032, Average AUC: 0.7658
# Epoch: 033, Average AUC: 0.7666
# Epoch: 034, Average AUC: 0.7677
# Epoch: 035, Average AUC: 0.7684
# Epoch: 036, Average AUC: 0.7688
# Epoch: 037, Average AUC: 0.7696
# Epoch: 038, Average AUC: 0.7703
# Epoch: 039, Average AUC: 0.7725
# Epoch: 040, Average AUC: 0.7733
# Epoch: 041, Average AUC: 0.7729
# Epoch: 042, Average AUC: 0.7737
# Epoch: 043, Average AUC: 0.7743
# Epoch: 044, Average AUC: 0.7758
# Epoch: 045, Average AUC: 0.7763
# Epoch: 046, Average AUC: 0.7768
# Epoch: 047, Average AUC: 0.7776
# Epoch: 048, Average AUC: 0.7782
# Epoch: 049, Average AUC: 0.7799
# Epoch: 050, Average AUC: 0.7805
# Epoch: 051, Average AUC: 0.7809
# Epoch: 052, Average AUC: 0.7815
# Epoch: 053, Average AUC: 0.7828
# Epoch: 054, Average AUC: 0.7842
# Epoch: 055, Average AUC: 0.7846
# Epoch: 056, Average AUC: 0.7859
# Epoch: 057, Average AUC: 0.7865
# Epoch: 058, Average AUC: 0.7870
# Epoch: 059, Average AUC: 0.7874
# Epoch: 060, Average AUC: 0.7878
# Epoch: 061, Average AUC: 0.7880
# Epoch: 062, Average AUC: 0.7887
# Epoch: 063, Average AUC: 0.7905
# Epoch: 064, Average AUC: 0.7909
# Epoch: 065, Average AUC: 0.7921
# Epoch: 066, Average AUC: 0.7931
# Epoch: 067, Average AUC: 0.7935
# Epoch: 068, Average AUC: 0.7938
# Epoch: 069, Average AUC: 0.7951
# Epoch: 070, Average AUC: 0.7951
# Epoch: 071, Average AUC: 0.7954
# Epoch: 072, Average AUC: 0.7957
# Epoch: 073, Average AUC: 0.7957
# Epoch: 074, Average AUC: 0.7970
# Epoch: 075, Average AUC: 0.7984
# Epoch: 076, Average AUC: 0.8002
# Epoch: 077, Average AUC: 0.8008
# Epoch: 078, Average AUC: 0.8008
# Epoch: 079, Average AUC: 0.8012
# Epoch: 080, Average AUC: 0.8025
# Epoch: 081, Average AUC: 0.8024
# Epoch: 082, Average AUC: 0.8028
# Epoch: 083, Average AUC: 0.8042
# Epoch: 084, Average AUC: 0.8044
# Epoch: 085, Average AUC: 0.8048
# Epoch: 086, Average AUC: 0.8054
# Epoch: 087, Average AUC: 0.8059
# Epoch: 088, Average AUC: 0.8067
# Epoch: 089, Average AUC: 0.8070
# Epoch: 090, Average AUC: 0.8082
# Epoch: 091, Average AUC: 0.8086
# Epoch: 092, Average AUC: 0.8089
# Epoch: 093, Average AUC: 0.8091
# Epoch: 094, Average AUC: 0.8094
# Epoch: 095, Average AUC: 0.8095
# Epoch: 096, Average AUC: 0.8102
# Epoch: 097, Average AUC: 0.8104
# Epoch: 098, Average AUC: 0.8117
# Epoch: 099, Average AUC: 0.8124
# Epoch: 100, Average AUC: 0.8119

# %%
from os import path
import pickle
import torch
import random
import numpy as np
import torch.nn.functional as F
from torch_geometric.nn import GATConv, GCNConv, SAGEConv
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from clotho.model.data_loader import get_data_loader
from clotho.model.new_data_loader import get_new_data_loader

def sample_one_degree_ego_network(edge_index, num_samples=10):
    ego_networks = {}
    for source_node, target_node in edge_index.t():
        if source_node.item() not in ego_networks:
            ego_networks[source_node.item()] = set()
        ego_networks[source_node.item()].add(target_node.item())
    for node in ego_networks:
        ego_networks[node] = list(ego_networks[node])
    return ego_networks

class CustomGraphSAGENet(torch.nn.Module):
    def __init__(self, num_features, num_classes, aggregation_type='mean'):
        super(CustomGraphSAGENet, self).__init__()
        self.conv1 = SAGEConv(num_features, 16, aggr=aggregation_type)
        self.conv2 = SAGEConv(16, num_classes, aggr=aggregation_type)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)

        ego_networks = sample_one_degree_ego_network(edge_index)
        aggregated_features = torch.zeros_like(x)
        for node, neighbors in ego_networks.items():
            neighbors_tensor = torch.tensor(neighbors, dtype=torch.long, device=x.device)
            aggregated_features[node] = x[neighbors_tensor].mean(dim=0)
        return aggregated_features

class GCNNet(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super(GCNNet, self).__init__()
        self.conv1 = GCNConv(num_features, 16)
        self.conv2 = GCNConv(16, num_classes)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x

class GraphSAGENet(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super(GraphSAGENet, self).__init__()
        self.conv1 = SAGEConv(num_features, 16)
        self.conv2 = SAGEConv(16, num_classes)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)
        return x

class Net(torch.nn.Module):
    def __init__(self):
        super().__init__()
        num_features = 4
        num_classes = 3
        self.conv1 = GATConv(num_features, 8, heads=2)
        self.lin1 = torch.nn.Linear(num_features, 2 * 8)
        self.conv2 = GATConv(2 * 8, 8, heads=2)
        self.lin2 = torch.nn.Linear(2 * 8, 2 * 8)
        self.conv3 = GATConv(2 * 8, num_classes, heads=2, concat=False)
        self.lin3 = torch.nn.Linear(2 * 8, num_classes)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index) + self.lin1(x))
        x = F.elu(self.conv2(x, edge_index) + self.lin2(x))
        x = self.conv3(x, edge_index) + self.lin3(x)
        return x

train_loader, test_loader = get_data_loader()
new_train_loader, new_test_loader = get_new_data_loader()

def run_experiment(model):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
    loss_op = torch.nn.BCEWithLogitsLoss()

    def train():
        model.train()
        total_loss = 0
        for data in train_loader:
            data = data.to(device)
            optimizer.zero_grad()
            output = model(data.x, data.edge_index)
            if torch.isnan(output).any() or torch.isinf(output).any():
                print("NaN or Inf in model output")
                continue
            loss = loss_op(output, data.y.float())
            if torch.isnan(loss) or torch.isinf(loss):
                print("NaN or Inf in loss")
                continue
            total_loss += loss.item() * data.num_graphs
            loss.backward()
            optimizer.step()
        return total_loss / len(train_loader.dataset)

    @torch.no_grad()
    def test(loader):
        model.eval()
        all_probs, all_labels = [], []
        for data in loader:
            data = data.to(device)
            out = model(data.x, data.edge_index)
            all_probs.append(out.cpu())
            all_labels.append(data.y.cpu())
        return all_probs, all_labels

    average_auc_scores = []
    for epoch in range(1, 101):
        train()
        probs, labels = test(test_loader)
        probs = torch.cat(probs, dim=0).sigmoid().numpy()
        labels = torch.cat(labels, dim=0).numpy()
        auc_scores = []
        for i in range(labels.shape[1]):
            fpr, tpr, _ = roc_curve(labels[:, i], probs[:, i])
            roc_auc = auc(fpr, tpr)
            auc_scores.append(roc_auc)
        average_auc = np.mean(auc_scores)
        average_auc_scores.append(average_auc)
        print(f"Epoch: {epoch:03d}, Average AUC: {average_auc:.4f}")

    plt.plot(range(1, 101), average_auc_scores, label="Average AUC")
    plt.xlabel("Epoch")
    plt.ylabel("Average AUC")
    plt.title("Average AUC per Epoch")
    plt.legend()
    plt.show()
    return average_auc_scores

num_features = 4  # Adjust this based on your dataset
num_classes = 3   # Adjust this based on your dataset

print("Running GAT Experiment")
gat_auc_scores = run_experiment(Net())

print("\nRunning GCN Experiment")
gcn_auc_scores = run_experiment(GCNNet(num_features, num_classes))

print("\nRunning GraphSAGE Experiment")
graphsage_auc_scores = run_experiment(GraphSAGENet(num_features, num_classes))

print("\nRunning Custom GraphSAGE Experiment")
custom_graphsage_auc_scores = run_experiment(CustomGraphSAGENet(num_features, num_classes, aggregation_type='max'))

plt.figure(figsize=(10, 6))
epochs = range(1, 101)
plt.plot(epochs, gat_auc_scores, label="GAT")
plt.plot(epochs, gcn_auc_scores, label="GCN")
plt.plot(epochs, graphsage_auc_scores, label="GraphSAGE")
plt.plot(epochs, custom_graphsage_auc_scores, label="Custom GraphSAGE")
plt.xlabel("Epoch")
plt.ylabel("Average AUC")
plt.title("Average AUC per Epoch for GAT, GCN, GraphSAGE, and Custom GraphSAGE")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py in line 81
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=77'>78</a>         x = self.conv3(x, edge_index) + self.lin3(x)
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=78'>79</a>         return x
# ---> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=80'>81</a> train_loader, test_loader = get_data_loader()
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=81'>82</a> new_train_loader, new_test_loader = get_new_data_loader()
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=83'>84</a> def run_experiment(model):
#
# File ~/ucl/paper_clotho/clotho/src/clotho/model/data_loader.py:63, in get_data_loader()
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/data_loader.py?line=61'>62</a> def get_data_loader():
# ---> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/data_loader.py?line=62'>63</a>     train_signals = get_train_scored_signals()
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/data_loader.py?line=63'>64</a>     processed_train_signals = process_dataframe(train_signals)
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/data_loader.py?line=64'>65</a>     ided_train_signals = assign_event_ids(processed_train_signals)
#
# File ~/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:81, in get_train_scored_signals(query)
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=75'>76</a> def get_train_scored_signals(query: str = TRAIN_QUERY_SCORED_PUMPS):
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=76'>77</a>     """
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=77'>78</a>     Get signals from the database for pre-pump scoring.
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=78'>79</a>     """
# ---> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=80'>81</a>     conn = psycopg2.connect(
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=81'>82</a>         f"dbname={GAIA_DB_DB} user={GAIA_DB_USER} password={GAIA_DB_PASSWORD} host={GAIA_DB_HOST} port={GAIA_DB_PORT}"
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=82'>83</a>     )
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=84'>85</a>     signals = pd.read_sql(query, conn)  # type: ignore
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py?line=86'>87</a>     conn.close()
#
# File ~/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/psycopg2/__init__.py?line=118'>119</a>     kwasync['async_'] = kwargs.pop('async_')
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/psycopg2/__init__.py?line=120'>121</a> dsn = _ext.make_dsn(dsn, **kwargs)
# --> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/psycopg2/__init__.py?line=121'>122</a> conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/psycopg2/__init__.py?line=122'>123</a> if cursor_factory is not None:
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/psycopg2/__init__.py?line=123'>124</a>     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "127.0.0.1", port 5433 failed: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.

# %%
from os import path
import pickle
import torch
import random
import numpy as np
import torch.nn.functional as F
from torch_geometric.nn import GATConv, GCNConv, SAGEConv
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from clotho.model.data_loader import get_data_loader
from clotho.model.new_data_loader import get_new_data_loader

def sample_one_degree_ego_network(edge_index, num_samples=10):
    ego_networks = {}
    for source_node, target_node in edge_index.t():
        if source_node.item() not in ego_networks:
            ego_networks[source_node.item()] = set()
        ego_networks[source_node.item()].add(target_node.item())
    for node in ego_networks:
        ego_networks[node] = list(ego_networks[node])
    return ego_networks

class CustomGraphSAGENet(torch.nn.Module):
    def __init__(self, num_features, num_classes, aggregation_type='mean'):
        super(CustomGraphSAGENet, self).__init__()
        self.conv1 = SAGEConv(num_features, 16, aggr=aggregation_type)
        self.conv2 = SAGEConv(16, num_classes, aggr=aggregation_type)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)

        ego_networks = sample_one_degree_ego_network(edge_index)
        aggregated_features = torch.zeros_like(x)
        for node, neighbors in ego_networks.items():
            neighbors_tensor = torch.tensor(neighbors, dtype=torch.long, device=x.device)
            aggregated_features[node] = x[neighbors_tensor].mean(dim=0)
        return aggregated_features

class GCNNet(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super(GCNNet, self).__init__()
        self.conv1 = GCNConv(num_features, 16)
        self.conv2 = GCNConv(16, num_classes)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x

class GraphSAGENet(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super(GraphSAGENet, self).__init__()
        self.conv1 = SAGEConv(num_features, 16)
        self.conv2 = SAGEConv(16, num_classes)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)
        return x

class Net(torch.nn.Module):
    def __init__(self):
        super().__init__()
        num_features = 4
        num_classes = 3
        self.conv1 = GATConv(num_features, 8, heads=2)
        self.lin1 = torch.nn.Linear(num_features, 2 * 8)
        self.conv2 = GATConv(2 * 8, 8, heads=2)
        self.lin2 = torch.nn.Linear(2 * 8, 2 * 8)
        self.conv3 = GATConv(2 * 8, num_classes, heads=2, concat=False)
        self.lin3 = torch.nn.Linear(2 * 8, num_classes)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index) + self.lin1(x))
        x = F.elu(self.conv2(x, edge_index) + self.lin2(x))
        x = self.conv3(x, edge_index) + self.lin3(x)
        return x

train_loader, test_loader = get_data_loader()
new_train_loader, new_test_loader = get_new_data_loader()

def run_experiment(model):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
    loss_op = torch.nn.BCEWithLogitsLoss()

    def train():
        model.train()
        total_loss = 0
        for data in train_loader:
            data = data.to(device)
            optimizer.zero_grad()
            output = model(data.x, data.edge_index)
            if torch.isnan(output).any() or torch.isinf(output).any():
                print("NaN or Inf in model output")
                continue
            loss = loss_op(output, data.y.float())
            if torch.isnan(loss) or torch.isinf(loss):
                print("NaN or Inf in loss")
                continue
            total_loss += loss.item() * data.num_graphs
            loss.backward()
            optimizer.step()
        return total_loss / len(train_loader.dataset)

    @torch.no_grad()
    def test(loader):
        model.eval()
        all_probs, all_labels = [], []
        for data in loader:
            data = data.to(device)
            out = model(data.x, data.edge_index)
            all_probs.append(out.cpu())
            all_labels.append(data.y.cpu())
        return all_probs, all_labels

    average_auc_scores = []
    for epoch in range(1, 101):
        train()
        probs, labels = test(test_loader)
        probs = torch.cat(probs, dim=0).sigmoid().numpy()
        labels = torch.cat(labels, dim=0).numpy()
        auc_scores = []
        for i in range(labels.shape[1]):
            fpr, tpr, _ = roc_curve(labels[:, i], probs[:, i])
            roc_auc = auc(fpr, tpr)
            auc_scores.append(roc_auc)
        average_auc = np.mean(auc_scores)
        average_auc_scores.append(average_auc)
        print(f"Epoch: {epoch:03d}, Average AUC: {average_auc:.4f}")

    plt.plot(range(1, 101), average_auc_scores, label="Average AUC")
    plt.xlabel("Epoch")
    plt.ylabel("Average AUC")
    plt.title("Average AUC per Epoch")
    plt.legend()
    plt.show()
    return average_auc_scores

num_features = 4  # Adjust this based on your dataset
num_classes = 3   # Adjust this based on your dataset

print("Running GAT Experiment")
gat_auc_scores = run_experiment(Net())

print("\nRunning GCN Experiment")
gcn_auc_scores = run_experiment(GCNNet(num_features, num_classes))

print("\nRunning GraphSAGE Experiment")
graphsage_auc_scores = run_experiment(GraphSAGENet(num_features, num_classes))

print("\nRunning Custom GraphSAGE Experiment")
custom_graphsage_auc_scores = run_experiment(CustomGraphSAGENet(num_features, num_classes, aggregation_type='max'))

plt.figure(figsize=(10, 6))
epochs = range(1, 101)
plt.plot(epochs, gat_auc_scores, label="GAT")
plt.plot(epochs, gcn_auc_scores, label="GCN")
plt.plot(epochs, graphsage_auc_scores, label="GraphSAGE")
plt.plot(epochs, custom_graphsage_auc_scores, label="Custom GraphSAGE")
plt.xlabel("Epoch")
plt.ylabel("Average AUC")
plt.title("Average AUC per Epoch for GAT, GCN, GraphSAGE, and Custom GraphSAGE")
plt.legend()
plt.show()
# Out:
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:74: RuntimeWarning: invalid value encountered in divide
#   D[i] = D[i] / np.sum(D[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:81: RuntimeWarning: invalid value encountered in divide
#   P[i] = P[i] / np.sum(P[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# train_data_prepared
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:74: RuntimeWarning: invalid value encountered in divide
#   D[i] = D[i] / np.sum(D[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:81: RuntimeWarning: invalid value encountered in divide
#   P[i] = P[i] / np.sum(P[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:67: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:74: RuntimeWarning: invalid value encountered in divide
#   D[i] = D[i] / np.sum(D[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:81: RuntimeWarning: invalid value encountered in divide
#   P[i] = P[i] / np.sum(P[i])
# Processing key: 1INCH
# Processing key: AAVE
# Skipping key ACA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ACM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ADA
# Processing key: ADX
# Skipping key AE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AERGO
# Processing key: AGI
# Processing key: AGIX
# Skipping key AGLD: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AION
# Skipping key AKRO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ALCX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ALGO
# Processing key: ALICE
# Skipping key ALPACA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ALPHA
# Skipping key ALPINE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AMB
# Skipping key ANC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ANKR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ANT
# Skipping key ANY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: APE
# Skipping key API3: Column 'telegram_chat_id' not found in DataFrame
# Processing key: APPC
# Skipping key AR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ARDR
# Processing key: ARK
# Processing key: ARN
# Processing key: ARPA
# Skipping key ASR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AST
# Skipping key ASTR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ATA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ATM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ATOM
# Skipping key AUCTION: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AUDIO
# Skipping key AVA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AVAX
# Processing key: AXS
# Skipping key BADGER: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BAKE
# Processing key: BAL
# Processing key: BAND
# Skipping key BAR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BAT
# Processing key: BCD
# Processing key: BCH
# Processing key: BCPT
# Skipping key BEAM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BEL
# Skipping key BETA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BICO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BLZ
# Processing key: BNB
# Skipping key BNX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOND: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BQX
# Processing key: BRD
# Processing key: BTC
# Skipping key BTG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BZRX
# Skipping key C98: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CAKE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CDT
# Processing key: CELO
# Processing key: CELR
# Skipping key CFX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CHR
# Processing key: CHZ
# Skipping key CKB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CLV: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CMT
# Skipping key CND: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COMP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: COTI
# Processing key: CRV
# Skipping key CTK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CTSI
# Processing key: CTXC
# Processing key: CVC
# Skipping key CVP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DASH
# Processing key: DATA
# Skipping key DCR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DEGO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DF: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DGB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DGD: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DIA
# Processing key: DLT
# Processing key: DNT
# Processing key: DOCK
# Processing key: DODO
# Processing key: DOGE
# Processing key: DOT
# Processing key: DREP
# Processing key: DUSK
# Processing key: DYDX
# Skipping key EASY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EDO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: EGLD
# Processing key: ELF
# Processing key: ENG
# Processing key: ENJ
# Skipping key ENS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: EOS
# Processing key: EPS
# Skipping key ERD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ERN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ETC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ETH
# Skipping key EUR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: EVX
# Skipping key EZ: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FARM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FET
# Skipping key FIDA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FIL
# Processing key: FIO
# Skipping key FIRO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FIS
# Skipping key FLM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FLOW: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FLUX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FORTH: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FRONT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FTM
# Skipping key FTT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FUEL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FUN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FXS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GAL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GALA
# Skipping key GAS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GLM
# Skipping key GLMR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GNT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GRS
# Processing key: GRT
# Skipping key GTC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GTO
# Skipping key GVT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GXS
# Processing key: HBAR
# Skipping key HC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key HIGH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: HIVE
# Processing key: HNT
# Skipping key HOT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ICP
# Skipping key ICX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: IDEX
# Skipping key IMX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: INJ
# Processing key: INS
# Processing key: IOST
# Skipping key IOTA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key IOTX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: IRIS
# Skipping key JASMY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key JST: Column 'telegram_chat_id' not found in DataFrame
# Skipping key JUV: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KAVA
# Skipping key KDON: Column 'telegram_chat_id' not found in DataFrame
# Skipping key KEEP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key KEY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key KLAY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KMD
# Processing key: KNC
# Skipping key KSM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key LAZIO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LEND
# Skipping key LINA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LINK
# Skipping key LIT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key LOKA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LOOM
# Skipping key LPT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LRC
# Skipping key LSK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LTC
# Processing key: LTO
# Skipping key LUN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LUNA
# Processing key: MANA
# Skipping key MASK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MATIC
# Skipping key MBL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MBOX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MDA
# Processing key: MDT
# Skipping key MDX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MINA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key MIR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MITH
# Processing key: MKR
# Skipping key MOVR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: MTH
# Processing key: MTL
# Skipping key MULTI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NANO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NAS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NAV
# Skipping key NBS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NBT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NEAR
# Processing key: NEBL
# Skipping key NEO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NKN
# Skipping key NMR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key NU: Column 'telegram_chat_id' not found in DataFrame
# Processing key: NULS
# Skipping key NXS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OAX
# Skipping key OCEAN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OGN
# Processing key: OM
# Processing key: OMG
# Processing key: ONG
# Skipping key ONT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key OOKI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ORN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: OST
# Processing key: OXT
# Skipping key PAXG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PEOPLE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PERL
# Skipping key PERP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PHA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PHB
# Skipping key PHX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PIVX
# Skipping key PLA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: PNT
# Processing key: POA
# Skipping key POE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: POLY
# Processing key: POND
# Skipping key PORTO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: POWR
# Processing key: PPT
# Skipping key PSG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key PYR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key QKC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: QLC
# Processing key: QSP
# Processing key: QTUM
# Skipping key RAD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key RARE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key RAY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RCN
# Processing key: RDN
# Skipping key REEF: Column 'telegram_chat_id' not found in DataFrame
# Processing key: REN
# Skipping key REP: Column 'telegram_chat_id' not found in DataFrame
# Processing key: REQ
# Skipping key RIF: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RLC
# Skipping key ROSE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: RSR
# Processing key: RUNE
# Processing key: RVN
# Processing key: SAND
# Skipping key SANTOS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SCRT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SFP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SHIB: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SKL
# Processing key: SKY
# Skipping key SLP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SNGLS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SNX
# Processing key: SOL
# Processing key: SRM
# Skipping key SSV: Column 'telegram_chat_id' not found in DataFrame
# Processing key: STEEM
# Skipping key STMX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: STORJ
# Skipping key STORM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: STPT
# Skipping key STRAT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key STRAX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key STX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key SUN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: SUSHI
# Processing key: SXP
# Processing key: SYS
# Processing key: TCT
# Processing key: TFUEL
# Processing key: THETA
# Skipping key TKO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TLM
# Skipping key TNB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key TNT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TOMO
# Skipping key TORN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TRB
# Skipping key TROY: Column 'telegram_chat_id' not found in DataFrame
# Processing key: TRU
# Processing key: TRX
# Processing key: TVK
# Skipping key TWT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key UMA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key UNFI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: UNI
# Skipping key UST: Column 'telegram_chat_id' not found in DataFrame
# Processing key: UTK
# Processing key: VET
# Skipping key VGX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: VIA
# Processing key: VIB
# Processing key: VIBE
# Processing key: VIDT
# Processing key: VITE
# Skipping key VOXEL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: WABI
# Processing key: WAN
# Processing key: WAVES
# Skipping key WING: Column 'telegram_chat_id' not found in DataFrame
# Processing key: WRX
# Processing key: WTC
# Skipping key XBT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XEM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: XLM
# Skipping key XMR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XNO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: XRP
# Processing key: XTZ
# Skipping key XVG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XVS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key XZC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: YFI
# Processing key: YFII
# Skipping key YGG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key YOYO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ZEC
# Processing key: ZEN
# Processing key: ZIL
# Skipping key ZRX: Column 'telegram_chat_id' not found in DataFrame
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# train_data_prepared
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/extract/cloudburst_connection.py:67: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   signals = pd.read_sql(query, conn)  # type: ignore
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:74: RuntimeWarning: invalid value encountered in divide
#   D[i] = D[i] / np.sum(D[i])
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/dataset/preprocess/DANI.py:81: RuntimeWarning: invalid value encountered in divide
#   P[i] = P[i] / np.sum(P[i])
# Skipping key 1000LUNC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key 1CAT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key 1EARTH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: 1INCH
# Processing key: AAVE
# Skipping key ABBC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ACA
# Processing key: ACE
# Processing key: ACH
# Skipping key ACM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ACQ: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ACS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ACT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ADA
# Skipping key ADS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ADX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AERGO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AGIX
# Processing key: AGLD
# Processing key: AI
# Skipping key AIPAD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AKITA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AKRO
# Skipping key AKT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ALCX
# Skipping key ALEPH: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ALEX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ALGO
# Processing key: ALICE
# Processing key: ALPACA
# Processing key: ALPHA
# Processing key: ALPINE
# Skipping key ALT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AMB
# Processing key: AMP
# Skipping key AMPL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ANKR
# Processing key: ANT
# Skipping key AOG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: APE
# Processing key: API3
# Skipping key APM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key APP: Column 'telegram_chat_id' not found in DataFrame
# Processing key: APT
# Processing key: AR
# Processing key: ARB
# Skipping key ARDR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ARG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ARIX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ARK
# Skipping key ARKER: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ARKM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ARPA
# Skipping key ARTY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ARX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ASR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AST
# Skipping key ASTR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ASTRA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ATA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ATM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ATOM
# Skipping key ATOR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AUCTION
# Processing key: AUDIO
# Skipping key AURORA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AUSD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AUTO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AVA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: AVAX
# Processing key: AXS
# Skipping key AZERO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key AZY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BABY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BABYDOGE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BADGER
# Processing key: BAKE
# Processing key: BAL
# Processing key: BAND
# Processing key: BAR
# Processing key: BAT
# Skipping key BAX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BBC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BCH
# Skipping key BDX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BEL
# Skipping key BEPRO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BETA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BETH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BICO
# Processing key: BIFI
# Skipping key BLOK: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BLUR
# Processing key: BLZ
# Processing key: BNB
# Skipping key BNBDOWN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BNBUP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BNT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BNX
# Skipping key BOA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOBA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOLT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BOND
# Skipping key BONDLY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BONE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BONK: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BORA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BORING: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BOSON: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BRISE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BRWL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BSV: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BSW: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BTC
# Skipping key BTC3L: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTC3S: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTCDOWN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTCUP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BTT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key BULL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: BURGER
# Skipping key BZZ: Column 'telegram_chat_id' not found in DataFrame
# Processing key: C98
# Skipping key CAKE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CANDY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CAPO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CAPP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CCD: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CEEK: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CEL: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CELO
# Processing key: CELR
# Skipping key CERE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CETUS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CFG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CFX
# Skipping key CGL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CGPT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CHESS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CHMB: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CHR
# Processing key: CHZ
# Skipping key CITY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CKB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CLH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CLV
# Skipping key CMP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COCOS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key COMBO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: COMP
# Skipping key CONV: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CORE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: COS
# Processing key: COTI
# Skipping key CPOOL: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CQT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CREAM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CREDI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CRO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CRV
# Skipping key CSIX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CSPR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CTC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CTI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CTK
# Processing key: CTSI
# Skipping key CTXC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CVC: Column 'telegram_chat_id' not found in DataFrame
# Processing key: CVP
# Processing key: CVX
# Skipping key CWAR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CWEB: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CWS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key CYBER: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAG: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAPPX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DAR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DASH
# Skipping key DATA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DBC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DCK: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DCR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DEGO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DENT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DEP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DERC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DEXE: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DFI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DGB
# Processing key: DIA
# Skipping key DIVI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DMTR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DOCK
# Processing key: DODO
# Processing key: DOGE
# Skipping key DOME: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DORA: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DOSE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DOT
# Skipping key DPR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DREAMS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DREP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key DSLA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DUSK
# Skipping key DVPN: Column 'telegram_chat_id' not found in DataFrame
# Processing key: DYDX
# Skipping key EDU: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EGAME: Column 'telegram_chat_id' not found in DataFrame
# Processing key: EGLD
# Skipping key EGO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ELF
# Skipping key ELON: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ENJ
# Processing key: ENS
# Processing key: EOS
# Skipping key EOSC: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EPIK: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EPX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ERG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ERN
# Skipping key ERTHA: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ETC
# Processing key: ETH
# Skipping key ETHDOWN: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ETHUP: Column 'telegram_chat_id' not found in DataFrame
# Skipping key ETHW: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EVMOS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key EWT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FARM
# Processing key: FET
# Processing key: FIDA
# Processing key: FIL
# Skipping key FIO: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FIRO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FIS
# Skipping key FITFI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key FLIP: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FLM
# Skipping key FLOKI: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FLOW
# Skipping key FLR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FLUX
# Skipping key FORTH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: FRONT
# Processing key: FTM
# Processing key: FTT
# Processing key: FUN
# Processing key: FXS
# Processing key: GAL
# Processing key: GALA
# Skipping key GARI: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GAS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GEARBOX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GFT: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GHST: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GLM: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GLMR: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GMX: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GNO
# Skipping key GNS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GODS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key GOG: Column 'telegram_chat_id' not found in DataFrame
# Processing key: GRT
# Processing key: GTC
# Processing key: HBAR
# Skipping key HFT: Column 'telegram_chat_id' not found in DataFrame
# Processing key: HIFI
# Processing key: HIGH
# Skipping key HIVE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: HNT
# Processing key: HOOK
# Processing key: HOT
# Processing key: ICP
# Processing key: ICX
# Skipping key ID: Column 'telegram_chat_id' not found in DataFrame
# Skipping key IDEX: Column 'telegram_chat_id' not found in DataFrame
# Skipping key IGU: Column 'telegram_chat_id' not found in DataFrame
# Processing key: ILV
# Processing key: IMX
# Processing key: INJ
# Processing key: IOST
# Processing key: IOTA
# Processing key: IOTX
# Skipping key IRIS: Column 'telegram_chat_id' not found in DataFrame
# Skipping key JAM: Column 'telegram_chat_id' not found in DataFrame
# Processing key: JASMY
# Processing key: JOE
# Skipping key JST: Column 'telegram_chat_id' not found in DataFrame
# Skipping key JTO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: JUV
# Skipping key KAR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KAVA
# Skipping key KCS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KDA
# Skipping key KEY: Column 'telegram_chat_id' not found in DataFrame
# Skipping key KINE: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KLAY
# Skipping key KMD: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KNC
# Skipping key KONO: Column 'telegram_chat_id' not found in DataFrame
# Processing key: KP3R
# Processing key: KSM
# Skipping key KSMU: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LAZIO
# Skipping key LBR: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LDO
# Skipping key LEASH: Column 'telegram_chat_id' not found in DataFrame
# Skipping key LET: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LEVER
# Processing key: LINA
# Skipping key LING: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LINK
# Processing key: LIT
# Skipping key LITH: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LOKA
# Skipping key LOOKS: Column 'telegram_chat_id' not found in DataFrame
# Processing key: LOOM
# Processing key: LPT
# Processing key: LQTY
# Processing key: LRC
# Processing key: LSK
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py in line 82
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=78'>79</a>         return x
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=80'>81</a> train_loader, test_loader = get_data_loader()
# ---> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=81'>82</a> new_train_loader, new_test_loader = get_new_data_loader()
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=83'>84</a> def run_experiment(model):
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/evaluation/comparison_epoch_auc.py?line=84'>85</a>     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# File ~/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py:113, in get_new_data_loader()
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=110'>111</a> market_features = features_engineer(processed_signals)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=111'>112</a> c = combine_features(market_features, f)
# --> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=112'>113</a> ngs = get_similar_graph(c)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=113'>114</a> label_mapping = create_label_mapping(3, "test")
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=115'>116</a> # Prepare data for training and testing sets
#
# File ~/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py:68, in get_similar_graph(features_dfs)
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=64'>65</a>     fi = features_df.loc[chat_id_1].values.reshape(1, -1)
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=65'>66</a>     fj = features_df.loc[chat_id_2].values.reshape(1, -1)
# ---> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=67'>68</a>     similarity = cosine_similarity(fi, fj)[0][0]
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=68'>69</a>     similarities[(chat_id_1, chat_id_2)] = similarity
#      <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/src/clotho/model/new_data_loader.py?line=70'>71</a> # Sort and keep the top half of the edges based on high weight
#
# File ~/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=204'>205</a> try:
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=205'>206</a>     with config_context(
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=206'>207</a>         skip_parameter_validation=(
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=207'>208</a>             prefer_skip_nested_validation or global_skip_validation
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=208'>209</a>         )
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=209'>210</a>     ):
# --> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=210'>211</a>         return func(*args, **kwargs)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=211'>212</a> except InvalidParameterError as e:
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=212'>213</a>     # When the function is just a wrapper around an estimator, we allow
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=213'>214</a>     # the function to delegate validation to the estimator, but we replace
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=214'>215</a>     # the name of the estimator by the name of the function in the error
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=215'>216</a>     # message to avoid confusion.
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=216'>217</a>     msg = re.sub(
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=217'>218</a>         r"parameter of \w+ must be",
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=218'>219</a>         f"parameter of {func.__qualname__} must be",
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=219'>220</a>         str(e),
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py?line=220'>221</a>     )
#
# File ~/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1578, in cosine_similarity(X, Y, dense_output)
#    <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1542'>1543</a> """Compute cosine similarity between samples in X and Y.
#    <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1543'>1544</a>
#    <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1544'>1545</a> Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1573'>1574</a>     Returns the cosine similarity between samples in X and Y.
#    <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1574'>1575</a> """
#    <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1575'>1576</a> # to avoid recursive import
# -> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1577'>1578</a> X, Y = check_pairwise_arrays(X, Y)
#    <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1579'>1580</a> X_normalized = normalize(X, copy=True)
#    <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=1580'>1581</a> if X is Y:
#
# File ~/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:173, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=163'>164</a> else:
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=164'>165</a>     X = check_array(
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=165'>166</a>         X,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=166'>167</a>         accept_sparse=accept_sparse,
#    (...)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=170'>171</a>         estimator=estimator,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=171'>172</a>     )
# --> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=172'>173</a>     Y = check_array(
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=173'>174</a>         Y,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=174'>175</a>         accept_sparse=accept_sparse,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=175'>176</a>         dtype=dtype,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=176'>177</a>         copy=copy,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=177'>178</a>         force_all_finite=force_all_finite,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=178'>179</a>         estimator=estimator,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=179'>180</a>     )
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=181'>182</a> if precomputed:
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py?line=182'>183</a>     if X.shape[1] != Y.shape[0]:
#
# File ~/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:957, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=950'>951</a>         raise ValueError(
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=951'>952</a>             "Found array with dim %d. %s expected <= 2."
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=952'>953</a>             % (array.ndim, estimator_name)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=953'>954</a>         )
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=955'>956</a>     if force_all_finite:
# --> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=956'>957</a>         _assert_all_finite(
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=957'>958</a>             array,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=958'>959</a>             input_name=input_name,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=959'>960</a>             estimator_name=estimator_name,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=960'>961</a>             allow_nan=force_all_finite == "allow-nan",
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=961'>962</a>         )
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=963'>964</a> if ensure_min_samples > 0:
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=964'>965</a>     n_samples = _num_samples(array)
#
# File ~/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:122, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=118'>119</a> if first_pass_isfinite:
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=119'>120</a>     return
# --> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=121'>122</a> _assert_all_finite_element_wise(
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=122'>123</a>     X,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=123'>124</a>     xp=xp,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=124'>125</a>     allow_nan=allow_nan,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=125'>126</a>     msg_dtype=msg_dtype,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=126'>127</a>     estimator_name=estimator_name,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=127'>128</a>     input_name=input_name,
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=128'>129</a> )
#
# File ~/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:171, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=153'>154</a> if estimator_name and input_name == "X" and has_nan_error:
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=154'>155</a>     # Improve the error message on how to handle missing values in
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=155'>156</a>     # scikit-learn.
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=156'>157</a>     msg_err += (
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=157'>158</a>         f"\n{estimator_name} does not accept missing values"
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=158'>159</a>         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=168'>169</a>         "#estimators-that-handle-nan-values"
#     <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=169'>170</a>     )
# --> <a href='file:///Users/honglinfu/ucl/paper_clotho/clotho/venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=170'>171</a> raise ValueError(msg_err)
#
# ValueError: Input contains NaN.
