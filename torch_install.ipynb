# %%
# !pip install torch torchvision

import torch
version = torch.__version__
i = version.find('+')
version = version[:i-1] + '0' + version[i:]
url = 'https://data.pyg.org/whl/torch-' + version + '.html'

# !pip install torch-scatter -f $url
# !pip install torch-sparse -f $url
# !pip install torch-geometric
# !pip install torch-cluster -f $url
# !pip install pygod
# !pip install --upgrade scipy
# Out:
# Requirement already satisfied: torch in ./venv/lib/python3.11/site-packages (2.1.0)
# Collecting torchvision
#   Using cached torchvision-0.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in ./venv/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.11/site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in ./venv/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in ./venv/lib/python3.11/site-packages (from torch) (2023.10.0)
# Collecting numpy (from torchvision)
#   Downloading numpy-1.26.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Collecting requests (from torchvision)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading Pillow-10.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Collecting charset-normalizer<4,>=2 (from requests->torchvision)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->torchvision)
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 5.6 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests->torchvision)
#   Downloading urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests->torchvision)
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: mpmath>=0.19 in ./venv/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Using cached torchvision-0.16.0-cp311-cp311-macosx_11_0_arm64.whl (1.6 MB)
# Downloading Pillow-10.1.0-cp311-cp311-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 31.2 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.26.1-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 23.3 MB/s eta 0:00:00a 0:00:01
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 6.1 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 18.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 13.6 MB/s eta 0:00:00
# Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 14.3 MB/s eta 0:00:00
# Installing collected packages: urllib3, pillow, numpy, idna, charset-normalizer, certifi, requests, torchvision
# Successfully installed certifi-2023.7.22 charset-normalizer-3.3.2 idna-3.4 numpy-1.26.1 pillow-10.1.0 requests-2.31.0 torchvision-0.16.0 urllib3-2.0.7
# Looking in links: https://data.pyg.org/whl/torch-2.100.html
# Collecting torch-scatter
#   Using cached torch_scatter-2.1.2.tar.gz (108 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-5k_6damk/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 355, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=['wheel'])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-5k_6damk/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 325, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-5k_6damk/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 507, in run_setup
#           super(_BuildMetaLegacyBackend, self).run_setup(setup_script=setup_script)
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-5k_6damk/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 341, in run_setup
#           exec(code, locals())
#         File "<string>", line 8, in <module>
#       ModuleNotFoundError: No module named 'torch'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Looking in links: https://data.pyg.org/whl/torch-2.100.html
# Collecting torch-sparse
#   Using cached torch_sparse-0.6.18.tar.gz (209 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-9x6oqbby/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 355, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=['wheel'])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-9x6oqbby/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 325, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-9x6oqbby/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 507, in run_setup
#           super(_BuildMetaLegacyBackend, self).run_setup(setup_script=setup_script)
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-9x6oqbby/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 341, in run_setup
#           exec(code, locals())
#         File "<string>", line 8, in <module>
#       ModuleNotFoundError: No module named 'torch'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting torch-geometric
#   Using cached torch_geometric-2.4.0-py3-none-any.whl.metadata (63 kB)
# Collecting tqdm (from torch-geometric)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: numpy in ./venv/lib/python3.11/site-packages (from torch-geometric) (1.26.1)
# Collecting scipy (from torch-geometric)
#   Using cached scipy-1.11.3-cp311-cp311-macosx_12_0_arm64.whl.metadata (165 kB)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.11/site-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: requests in ./venv/lib/python3.11/site-packages (from torch-geometric) (2.31.0)
# Collecting pyparsing (from torch-geometric)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting scikit-learn (from torch-geometric)
#   Using cached scikit_learn-1.3.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: psutil>=5.8.0 in ./venv/lib/python3.11/site-packages (from torch-geometric) (5.9.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from jinja2->torch-geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests->torch-geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests->torch-geometric) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.11/site-packages (from requests->torch-geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.11/site-packages (from requests->torch-geometric) (2023.7.22)
# Collecting joblib>=1.1.1 (from scikit-learn->torch-geometric)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->torch-geometric)
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Using cached torch_geometric-2.4.0-py3-none-any.whl (1.0 MB)
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 3.3 MB/s eta 0:00:00
# Using cached scikit_learn-1.3.2-cp311-cp311-macosx_12_0_arm64.whl (9.4 MB)
# Downloading scipy-1.11.3-cp311-cp311-macosx_12_0_arm64.whl (29.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 26.0 MB/s eta 0:00:0000:0100:01
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: tqdm, threadpoolctl, scipy, pyparsing, joblib, scikit-learn, torch-geometric
# Successfully installed joblib-1.3.2 pyparsing-3.1.1 scikit-learn-1.3.2 scipy-1.11.3 threadpoolctl-3.2.0 torch-geometric-2.4.0 tqdm-4.66.1
# Looking in links: https://data.pyg.org/whl/torch-2.100.html
# Collecting torch-cluster
#   Using cached torch_cluster-1.6.3.tar.gz (54 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/franciscorua/Desktop/Work/Cloudburst/repositories/perseus/venv/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-59ma6ia_/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 355, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=['wheel'])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-59ma6ia_/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 325, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-59ma6ia_/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 507, in run_setup
#           super(_BuildMetaLegacyBackend, self).run_setup(setup_script=setup_script)
#         File "/private/var/folders/sn/459v8ly907x12pplc4jll66r0000gn/T/pip-build-env-59ma6ia_/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 341, in run_setup
#           exec(code, locals())
#         File "<string>", line 8, in <module>
#       ModuleNotFoundError: No module named 'torch'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting pygod
#   Using cached pygod-1.0.0-py3-none-any.whl
# Requirement already satisfied: numpy in ./venv/lib/python3.11/site-packages (from pygod) (1.26.1)
# Requirement already satisfied: scipy in ./venv/lib/python3.11/site-packages (from pygod) (1.11.3)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (from pygod) (3.2.1)
# Requirement already satisfied: scikit-learn in ./venv/lib/python3.11/site-packages (from pygod) (1.3.2)
# Requirement already satisfied: setuptools in ./venv/lib/python3.11/site-packages (from pygod) (65.5.0)
# Requirement already satisfied: joblib>=1.1.1 in ./venv/lib/python3.11/site-packages (from scikit-learn->pygod) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./venv/lib/python3.11/site-packages (from scikit-learn->pygod) (3.2.0)
# Installing collected packages: pygod
# Successfully installed pygod-1.0.0
# Requirement already satisfied: scipy in ./venv/lib/python3.11/site-packages (1.11.3)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in ./venv/lib/python3.11/site-packages (from scipy) (1.26.1)
